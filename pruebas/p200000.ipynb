# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import random
import math
from scipy.spatial import distance_matrix

# Configuración de parámetros
POPULATION_SIZE = 150
GENERATIONS = 200000
MUTATION_RATE = 0.4
ELITE_SIZE = 5

# Cargar datos desde el archivo .txt
def load_tsp_data(file_path):
    coords = []
    with open(file_path, 'r') as f:
        lines = f.readlines()
        start_index = lines.index('NODE_COORD_SECTION\n') + 1
        for line in lines[start_index:]:
            if line.strip() == 'EOF':
                break
            _, x, y = line.split()
            coords.append((float(x), float(y)))
    return np.array(coords)

# Generar una ruta aleatoria
def create_route(cities):
    return random.sample(list(cities), len(cities))

# Calcular la distancia de la ruta
def route_distance(route, dist_matrix):
    return sum(dist_matrix[route[i], route[i + 1]] for i in range(len(route) - 1)) + dist_matrix[route[-1], route[0]]

# Crear la población inicial
def create_population(pop_size, cities):
    return [create_route(cities) for _ in range(pop_size)]

# Selección de los mejores individuos
def rank_routes(population, dist_matrix):
    fitness_results = {i: route_distance(ind, dist_matrix) for i, ind in enumerate(population)}
    return sorted(fitness_results.items(), key=lambda x: x[1])

# Selección por torneo
def selection(ranked_population):
    selected = []
    for i in range(ELITE_SIZE):
        selected.append(ranked_population[i][0])
    for i in range(len(ranked_population) - ELITE_SIZE):
        selected.append(random.choice(ranked_population[:POPULATION_SIZE // 2])[0])
    return selected

# Cruzar dos padres
def breed(parent1, parent2):
    start, end = sorted(random.sample(range(len(parent1)), 2))
    child = parent1[start:end]
    child += [item for item in parent2 if item not in child]
    return child

# Aplicar mutación 2-Opt
def mutate(individual, mutation_rate):
    if random.random() < mutation_rate:
        i, j = sorted(random.sample(range(len(individual)), 2))
        individual[i:j] = individual[i:j][::-1]  # Inversión de una sección
    return individual

# Crear la nueva generación
def evolve_population(population, dist_matrix):
    ranked_population = rank_routes(population, dist_matrix)
    selected_indices = selection(ranked_population)
    selected_population = [population[i] for i in selected_indices]
    children = [breed(selected_population[i], selected_population[-i-1]) for i in range(len(selected_population) - ELITE_SIZE)]
    mutated_population = [mutate(ind, MUTATION_RATE) for ind in children]
    return selected_population[:ELITE_SIZE] + mutated_population

# Generar la animación
def animate_solution(cities, history):
    fig, ax = plt.subplots()
    line, = ax.plot([], [], 'o-', lw=2)

    def init():
        line.set_data([], [])
        return line,

    def update(frame):
        x = [cities[city][0] for city in history[frame]]
        y = [cities[city][1] for city in history[frame]]
        line.set_data(x + [x[0]], y + [y[0]])
        return line,

    ani = FuncAnimation(fig, update, frames=len(history), init_func=init, blit=True, repeat=False)
    plt.show()
    ani.save('tsp_solution.gif', writer='imagemagick')

# Ejecutar el algoritmo
def genetic_algorithm_tsp(file_path):
    cities = load_tsp_data(file_path)
    dist_matrix = distance_matrix(cities, cities)
    population = create_population(POPULATION_SIZE, range(len(cities)))

    history = []
    for generation in range(GENERATIONS):
        population = evolve_population(population, dist_matrix)
        best_route_idx, best_distance = rank_routes(population, dist_matrix)[0]
        best_route = population[best_route_idx]

        # Guardar cada 1000 iteraciones para la animación
        if generation % 1000 == 0:
            history.append(best_route)

        if generation % 1000 == 0:
            print(f"Generación {generation} - Distancia óptima: {best_distance}")

    # Animar la solución
    animate_solution(cities, history)
    print("Tour óptimo encontrado:", best_route)
    print("Distancia total:", best_distance)

# Ruta al archivo .txt
file_path = 'ch150r.txt'
genetic_algorithm_tsp(file_path)
# Out:
# Generación 0 - Distancia óptima: 47570.63847458849
# Generación 1000 - Distancia óptima: 18225.598973791926
# Generación 2000 - Distancia óptima: 17042.38346580768
# Generación 3000 - Distancia óptima: 15783.465496651861
# Generación 4000 - Distancia óptima: 14899.750113301698
# Generación 5000 - Distancia óptima: 14433.869579142824
# Generación 6000 - Distancia óptima: 14150.139918485995
# Generación 7000 - Distancia óptima: 14133.990602213238
# Generación 8000 - Distancia óptima: 13881.010753480514
# Generación 9000 - Distancia óptima: 13735.039914496552
# Generación 10000 - Distancia óptima: 13672.711082650017
# Generación 11000 - Distancia óptima: 13672.711082650017
# Generación 12000 - Distancia óptima: 13661.389551153905
# Generación 13000 - Distancia óptima: 13589.084955154627
# Generación 14000 - Distancia óptima: 13472.809585027171
# Generación 15000 - Distancia óptima: 13431.782864990448
# Generación 16000 - Distancia óptima: 13110.094738832344
# Generación 17000 - Distancia óptima: 12985.323817794302
# Generación 18000 - Distancia óptima: 12873.718505761492
# Generación 19000 - Distancia óptima: 12850.970772535367
# Generación 20000 - Distancia óptima: 12717.224423705085
# Generación 21000 - Distancia óptima: 12553.985952156441
# Generación 22000 - Distancia óptima: 12553.985952156441
# Generación 23000 - Distancia óptima: 12543.149689783953
# Generación 24000 - Distancia óptima: 12543.149689783953
# Generación 25000 - Distancia óptima: 12474.372865077217
# Generación 26000 - Distancia óptima: 12427.480050806116
# Generación 27000 - Distancia óptima: 12081.13410869968
# Generación 28000 - Distancia óptima: 12054.210595128747
# Generación 29000 - Distancia óptima: 12029.231185004248
# Generación 30000 - Distancia óptima: 11884.3274822233
# Generación 31000 - Distancia óptima: 11818.74014746404
# Generación 32000 - Distancia óptima: 11683.802933179863
# Generación 33000 - Distancia óptima: 11633.192300736717
# Generación 34000 - Distancia óptima: 11620.799160070594
# Generación 35000 - Distancia óptima: 11620.799160070594
# Generación 36000 - Distancia óptima: 11575.484374321628
# Generación 37000 - Distancia óptima: 11572.642020525791
# Generación 38000 - Distancia óptima: 11470.764246428864
# Generación 39000 - Distancia óptima: 11322.936109963784
# Generación 40000 - Distancia óptima: 11322.936109963784
# Generación 41000 - Distancia óptima: 11248.866229706582
# Generación 42000 - Distancia óptima: 11221.255585722616
# Generación 43000 - Distancia óptima: 11221.255585722616
# Generación 44000 - Distancia óptima: 11221.255585722616
# Generación 45000 - Distancia óptima: 11218.315650802268
# Generación 46000 - Distancia óptima: 11218.315650802268
# Generación 47000 - Distancia óptima: 11109.827604370455
# Generación 48000 - Distancia óptima: 11109.827604370455
# Generación 49000 - Distancia óptima: 11031.181949678477
# Generación 50000 - Distancia óptima: 10992.571459661429
# Generación 51000 - Distancia óptima: 10762.447333660066
# Generación 52000 - Distancia óptima: 10691.636699961851
# Generación 53000 - Distancia óptima: 10691.636699961851
# Generación 54000 - Distancia óptima: 10517.915262637429
# Generación 55000 - Distancia óptima: 10514.243371118522
# Generación 56000 - Distancia óptima: 10246.64957503835
# Generación 57000 - Distancia óptima: 10246.64957503835
# Generación 58000 - Distancia óptima: 10189.829610711307
# Generación 59000 - Distancia óptima: 10116.3480554388
# Generación 60000 - Distancia óptima: 10090.811685758368
# Generación 61000 - Distancia óptima: 10090.811685758368
# Generación 62000 - Distancia óptima: 10077.171993789396
# Generación 63000 - Distancia óptima: 10059.358649339709
# Generación 64000 - Distancia óptima: 10000.145755237963
# Generación 65000 - Distancia óptima: 10000.145755237963
# Generación 66000 - Distancia óptima: 10000.145755237963
# Generación 67000 - Distancia óptima: 9872.63628206179
# Generación 68000 - Distancia óptima: 9872.63628206179
# Generación 69000 - Distancia óptima: 9810.695505760628
# Generación 70000 - Distancia óptima: 9764.81081194118
# Generación 71000 - Distancia óptima: 9764.81081194118
# Generación 72000 - Distancia óptima: 9723.054891842356
# Generación 73000 - Distancia óptima: 9723.054891842356
# Generación 74000 - Distancia óptima: 9723.054891842356
# Generación 75000 - Distancia óptima: 9723.054891842356
# Generación 76000 - Distancia óptima: 9723.054891842356
# Generación 77000 - Distancia óptima: 9717.987435309053
# Generación 78000 - Distancia óptima: 9717.987435309053
# Generación 79000 - Distancia óptima: 9717.987435309053
# Generación 80000 - Distancia óptima: 9702.233051724283
# Generación 81000 - Distancia óptima: 9702.233051724283
# Generación 82000 - Distancia óptima: 9702.233051724283
# Generación 83000 - Distancia óptima: 9702.233051724283
# Generación 84000 - Distancia óptima: 9687.921754801191
# Generación 85000 - Distancia óptima: 9687.921754801191
# Generación 86000 - Distancia óptima: 9681.989617615583
# Generación 87000 - Distancia óptima: 9681.989617615583
# Generación 88000 - Distancia óptima: 9629.59533633636
# Generación 89000 - Distancia óptima: 9581.620762221293
# Generación 90000 - Distancia óptima: 9581.620762221293
# Generación 91000 - Distancia óptima: 9444.473539920926
# Generación 92000 - Distancia óptima: 9444.473539920926
# Generación 93000 - Distancia óptima: 9444.473539920926
# Generación 94000 - Distancia óptima: 9444.473539920926
# Generación 95000 - Distancia óptima: 9438.309660489806
# Generación 96000 - Distancia óptima: 9438.309660489806
# Generación 97000 - Distancia óptima: 9438.309660489806
# Generación 98000 - Distancia óptima: 9438.309660489806
# Generación 99000 - Distancia óptima: 9438.309660489806
# Generación 100000 - Distancia óptima: 9438.309660489806
# Generación 101000 - Distancia óptima: 9438.309660489806
# Generación 102000 - Distancia óptima: 9438.309660489806
# Generación 103000 - Distancia óptima: 9405.028905387933
# Generación 104000 - Distancia óptima: 9365.82839690143
# Generación 105000 - Distancia óptima: 9365.82839690143
# Generación 106000 - Distancia óptima: 9365.82839690143
# Generación 107000 - Distancia óptima: 9365.82839690143
# Generación 108000 - Distancia óptima: 9338.254090853467
# Generación 109000 - Distancia óptima: 9275.89907622623
# Generación 110000 - Distancia óptima: 9205.824431700596
# Generación 111000 - Distancia óptima: 9145.982830810992
# Generación 112000 - Distancia óptima: 9139.700017333429
# Generación 113000 - Distancia óptima: 9135.138941177845
# Generación 114000 - Distancia óptima: 9135.138941177845
# Generación 115000 - Distancia óptima: 9135.138941177845
# Generación 116000 - Distancia óptima: 9129.82658888571
# Generación 117000 - Distancia óptima: 9129.82658888571
# Generación 118000 - Distancia óptima: 9129.82658888571
# Generación 119000 - Distancia óptima: 9129.82658888571
# Generación 120000 - Distancia óptima: 9129.82658888571
# Generación 121000 - Distancia óptima: 9129.82658888571
# Generación 122000 - Distancia óptima: 9129.638087648871
# Generación 123000 - Distancia óptima: 9129.638087648871
# Generación 124000 - Distancia óptima: 9129.638087648871
# Generación 125000 - Distancia óptima: 9119.310829689855
# Generación 126000 - Distancia óptima: 9093.15308527107
# Generación 127000 - Distancia óptima: 9093.15308527107
# Generación 128000 - Distancia óptima: 9093.15308527107
# Generación 129000 - Distancia óptima: 9090.732485929888
# Generación 130000 - Distancia óptima: 9081.466905963745
# Generación 131000 - Distancia óptima: 9044.183691703456
# Generación 132000 - Distancia óptima: 8997.049974633916
# Generación 133000 - Distancia óptima: 8997.049974633916
# Generación 134000 - Distancia óptima: 8997.049974633916
# Generación 135000 - Distancia óptima: 8997.049974633916
# Generación 136000 - Distancia óptima: 8997.049974633916
# Generación 137000 - Distancia óptima: 8989.726777811811
# Generación 138000 - Distancia óptima: 8977.861757611865
# Generación 139000 - Distancia óptima: 8977.861757611865
# Generación 140000 - Distancia óptima: 8977.861757611865
# Generación 141000 - Distancia óptima: 8817.15818776059
# Generación 142000 - Distancia óptima: 8668.30242146557
# Generación 143000 - Distancia óptima: 8668.30242146557
# Generación 144000 - Distancia óptima: 8668.30242146557
# Generación 145000 - Distancia óptima: 8633.53614617222
# Generación 146000 - Distancia óptima: 8509.682706430205
# Generación 147000 - Distancia óptima: 8509.682706430205
# Generación 148000 - Distancia óptima: 8509.682706430205
# Generación 149000 - Distancia óptima: 8474.916431136855
# Generación 150000 - Distancia óptima: 8412.0100573933
# Generación 151000 - Distancia óptima: 8389.849134242171
# Generación 152000 - Distancia óptima: 8389.849134242171
# Generación 153000 - Distancia óptima: 8389.849134242171
# Generación 154000 - Distancia óptima: 8389.849134242171
# Generación 155000 - Distancia óptima: 8378.106993854595
# Generación 156000 - Distancia óptima: 8378.106993854595
# Generación 157000 - Distancia óptima: 8356.754111091337
# Generación 158000 - Distancia óptima: 8356.754111091337
# Generación 159000 - Distancia óptima: 8356.754111091337
# Generación 160000 - Distancia óptima: 8356.754111091337
# Generación 161000 - Distancia óptima: 8356.754111091337
# Generación 162000 - Distancia óptima: 8351.277486139172
# Generación 163000 - Distancia óptima: 8351.277486139172
# Generación 164000 - Distancia óptima: 8351.277486139172
# Generación 165000 - Distancia óptima: 8351.277486139172
# Generación 166000 - Distancia óptima: 8351.277486139172
# Generación 167000 - Distancia óptima: 8339.93770234911
# Generación 168000 - Distancia óptima: 8332.094377550464
# Generación 169000 - Distancia óptima: 8332.094377550464
# Generación 170000 - Distancia óptima: 8332.094377550464
# Generación 171000 - Distancia óptima: 8332.094377550464
# Generación 172000 - Distancia óptima: 8332.094377550464
# Generación 173000 - Distancia óptima: 8332.094377550464
# Generación 174000 - Distancia óptima: 8332.094377550464
# Generación 175000 - Distancia óptima: 8327.939809375035
# Generación 176000 - Distancia óptima: 8304.07053732578
# Generación 177000 - Distancia óptima: 8304.07053732578
# Generación 178000 - Distancia óptima: 8304.07053732578
# Generación 179000 - Distancia óptima: 8304.07053732578
# Generación 180000 - Distancia óptima: 8304.07053732578
# Generación 181000 - Distancia óptima: 8270.378628446708
# Generación 182000 - Distancia óptima: 8263.655134961535
# Generación 183000 - Distancia óptima: 8263.655134961535
# Generación 184000 - Distancia óptima: 8263.655134961535
# Generación 185000 - Distancia óptima: 8263.655134961535
# Generación 186000 - Distancia óptima: 8263.655134961535
# Generación 187000 - Distancia óptima: 8263.655134961535
# Generación 188000 - Distancia óptima: 8263.655134961535
# Generación 189000 - Distancia óptima: 8263.655134961535
# Generación 190000 - Distancia óptima: 8212.091076165167
# Generación 191000 - Distancia óptima: 8212.091076165167
# Generación 192000 - Distancia óptima: 8212.091076165167
# Generación 193000 - Distancia óptima: 8191.56775915082
# Generación 194000 - Distancia óptima: 8191.56775915082
# Generación 195000 - Distancia óptima: 8191.56775915082
# Generación 196000 - Distancia óptima: 8191.56775915082
# Generación 197000 - Distancia óptima: 8191.56775915082
# Generación 198000 - Distancia óptima: 8191.56775915082
# Generación 199000 - Distancia óptima: 8191.56775915082
# WARNING:matplotlib.animation:MovieWriter imagemagick unavailable; using Pillow instead.
# Tour óptimo encontrado: [43, 70, 44, 127, 67, 118, 90, 105, 12, 73, 122, 30, 26, 128, 143, 146, 48, 40, 100, 115, 56, 116, 38, 139, 16, 65, 59, 129, 147, 10, 126, 68, 60, 35, 117, 52, 46, 19, 138, 119, 36, 5, 8, 27, 41, 39, 23, 11, 42, 108, 50, 137, 53, 91, 45, 89, 82, 55, 25, 145, 96, 123, 7, 88, 83, 6, 29, 33, 47, 62, 112, 9, 95, 34, 92, 125, 32, 110, 104, 51, 132, 14, 77, 78, 58, 15, 120, 93, 87, 20, 149, 114, 3, 103, 21, 124, 148, 61, 2, 72, 75, 86, 0, 97, 102, 94, 81, 106, 4, 99, 142, 141, 17, 74, 64, 84, 131, 54, 57, 49, 134, 136, 101, 98, 113, 18, 1, 107, 28, 69, 85, 80, 109, 140, 24, 133, 130, 31, 66, 37, 22, 76, 121, 13, 79, 71, 144, 135, 111, 63]
# Distancia total: 8191.56775915082
